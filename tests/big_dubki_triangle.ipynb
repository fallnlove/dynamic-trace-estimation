# %%
hutch = [2.167238095238095, 1.6986285714285716, 2.0285714285714285, 2.227161904761904, 2.257752380952381, 1.9623999999999995, 2.063961904761904, 2.7336761904761904, 1.969828571428572, 1.7208000000000003, 2.04655238095238, 2.4895238095238095, 1.95127619047619, 1.9123809523809527, 2.1344, 2.22407619047619, 1.9390476190476187, 2.1372571428571425, 1.772190476190476, 2.4041523809523806, 2.079923809523809, 2.012304761904762, 2.0459809523809525, 2.011695238095238, 2.169676190476191, 1.89592380952381, 1.8024380952380952, 2.2807999999999997, 2.4705523809523813, 1.9569523809523814, 2.0381714285714283, 2.358971428571429, 2.2224761904761907, 2.4515809523809526, 2.078590476190476, 2.2968380952380953, 1.8855619047619046, 1.8009142857142857, 1.9975238095238097, 1.9683809523809523, 2.4014095238095234, 2.1524952380952382, 2.224076190476191, 1.985066666666667, 1.8788952380952388, 2.5414095238095236, 1.8258666666666665, 2.1453714285714285, 2.084190476190476, 2.1371809523809526, 2.2508571428571424, 1.8714666666666664, 2.063580952380952, 1.9570285714285711, 2.082628571428571, 2.078590476190477, 2.1049904761904763, 2.1429333333333336, 2.3138285714285716, 1.976609523809524, 1.7131428571428569, 2.0130666666666666, 1.9534476190476187, 2.019390476190477, 2.120495238095238, 1.6340952380952385, 1.9314285714285715, 1.9109333333333336, 1.7897523809523812, 2.0221714285714283, 2.0596190476190475, 2.1512761904761906, 1.9172952380952382, 1.6748952380952387, 2.1703999999999994, 2.1900571428571434, 2.0152380952380953, 1.8401142857142858, 1.9257142857142855, 2.065180952380952, 1.7959619047619049, 1.8710095238095237, 2.2072000000000003, 1.9364571428571427, 1.9012952380952384, 1.6366476190476191, 2.3085333333333327, 1.996609523809524, 1.9694095238095237, 2.222742857142857, 2.0799619047619045, 1.861219047619047, 2.076228571428571, 1.7503619047619048, 2.409790476190476, 1.6512761904761906, 2.1663619047619047, 2.3396190476190473, 2.19687619047619, 2.133142857142857, 1.8344000000000003, 1.707733333333333, 1.734095238095238, 1.9241142857142857, 2.2341714285714276, 2.000723809523809, 1.762819047619047, 2.0023619047619046, 2.022552380952381, 2.18392380952381, 1.6095999999999997, 1.9288000000000003, 1.9682666666666662, 2.1718476190476195, 1.7214476190476193, 1.775161904761905, 1.8869333333333336, 2.303961904761905]
hutchpp = [1.9947786205850928, 1.787751843025598, 1.7834621118070424, 1.8736165168088215, 1.7320438703959777, 1.7184597290649832, 1.5205107371318791, 1.7692058520449445, 1.5894059739014421, 1.8991380004185112, 1.9751131405847493, 1.7011970653971722, 1.7409720543719147, 1.7442291897504034, 2.029953789480576, 1.9048555254080837, 1.8614223484634511, 1.7020301562788276, 1.5634809947944879, 1.6211821020237012, 1.744519354440863, 1.693030725163989, 1.8923444594389252, 1.793630624029933, 1.685614156594793, 1.7772582621237272, 2.010564128573286, 1.5675809675305101, 1.688056455537989, 1.6718811016737072, 1.8767549482199795, 1.910047435379658, 1.919787465895287, 1.6578653731229664, 1.9520834731086263, 2.06594543083167, 1.6225125810890892, 1.7367628471934546, 1.9005562394708284, 1.9614681551232842, 1.7612902849196999, 1.9417986949565096, 1.9018894263978308, 1.4760409961884713, 1.7520699505815913, 1.531238741645422, 1.66754792970608, 1.8366042619939498, 1.9592501734241994, 1.7249330047380347, 1.776123780565993, 1.5561101326614475, 1.6156570723661556, 1.4038989503587722, 1.7919239803561482, 1.7575906038970073, 1.849974609191059, 1.8730627594588634, 1.9790002538435931, 1.5621684755686684, 1.6220437469698743, 1.4080073131658895, 1.594265120276003, 1.6371431174787245, 1.4141499698246767, 1.5234361959814162, 1.651778747103796, 1.5234142689429726, 1.8454458030365983, 1.2800562771008217, 1.7055362809648849, 1.5823744304262335, 1.8310906328103087, 1.3448514299402037, 1.705041121413781, 1.4992772285295999, 1.4953356912213738, 1.7135684627734116, 1.7348611285168363, 1.1963924401383503, 2.1546641700317952, 1.7399909009840826, 1.8629677071618027, 1.6922587810407312, 1.6538797886637118, 1.750479019537921, 1.5987610256662361, 1.5200919010529745, 1.720595078321517, 1.7228039154607597, 1.7606419553282209, 1.7262326301039126, 1.654064557241132, 1.5798876419878538, 1.946796063216114, 1.4818035910628544, 1.5931480821613229, 1.7060584560981953, 1.8537291065787276, 1.8559134104609505, 1.5574890286387528, 1.4426472372728016, 1.5774813451082204, 1.415054141854412, 1.4606332553906787, 1.740433121978337, 1.646724211621231, 1.8545337398333606, 1.7284250446645728, 1.8872984607423007, 1.9225493013957407, 1.6486621328983813, 1.7228295302461303, 1.8993335583363204, 1.690439270818287, 1.6699664197544664, 1.3963856623032378, 1.608790600156017]
deltashift = [1.7218476190476184, 1.523829635173626, 1.3881555746528897, 1.3274031110227202, 1.3000239388178327, 1.1734210298362955, 1.1679304790014087, 1.199804202562198, 1.1452950534892237, 1.178011897222887, 1.1363640334439553, 1.0624240490847061, 1.0179270561450828, 1.0040502841632524, 0.9944694973515942, 0.9684833602576446, 0.9518305377925931, 0.9768598488494747, 0.9965712034783859, 0.984433455714258, 0.9726948581050582, 0.9574476671633542, 0.9683814616757218, 0.9817725741057082, 0.9722782241630412, 0.9660510180009002, 0.951967755361151, 0.9460924940031312, 0.9464847398911332, 0.9467050506123392, 0.9301142606588482, 0.9191712633792264, 0.8997563181642723, 0.9076065383420179, 0.9062641197421738, 0.8971620417652985, 0.8885765048442869, 0.9108424676971325, 0.9144412389426242, 0.9132437717022052, 0.9149332056226542, 0.9092147547705978, 0.9131694882008736, 0.7956431857413733, 0.7895402930642471, 0.7871138335195993, 0.7768082203283242, 0.7836375273659629, 0.7753532585028807, 0.7750305771633537, 0.7803613758721726, 0.7703352420852572, 0.7680325066976005, 0.7722817544629962, 0.7776677077134755, 0.7735586789304459, 0.7810636645839866, 0.7756836229490871, 0.7734666190451043, 0.7507909811290311, 0.7417887259705854, 0.7438692331335175, 0.6232952093029622, 0.62048653631395, 0.6375744723958631, 0.6432650139008294, 0.640394642958996, 0.6383592129798004, 0.6495034430697184, 0.6491742013219272, 0.6462131307095299, 0.6386258125418537, 0.6283850553170127, 0.6291350223885853, 0.6313156860408328, 0.6281984644023967, 0.6260119690354035, 0.6256815013331972, 0.6123677376256965, 0.5075641327285484, 0.4976200460837812, 0.5051137451983841, 0.5141461163249132, 0.512317703201274, 0.5213734627805158, 0.5207484858447906, 0.5141971248218382, 0.5116482110165708, 0.5144339583865295, 0.5105450532117097, 0.5164343982319274, 0.5200280294458434, 0.5160549081411865, 0.5200278998555686, 0.5126921839231688, 0.5022874320655819, 0.501505644158953, 0.4991421973906147, 0.4905389022091181, 0.38614225471490643, 0.3761415493434795, 0.37293118667749175, 0.3733230588080398, 0.37370700922976446, 0.3764068287098609, 0.37880375084366913, 0.38453848334691615, 0.38219264018167737, 0.38281584921442247, 0.3877543233428591, 0.390377053164274, 0.2681111521399649, 0.2641187747370079, 0.265595194328315, 0.271493375428906, 0.270236017779792, 0.2681040262861593, 0.27156771574511046]
deltashiftrest = [1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.4600571428571427, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6471047619047616, 1.6877904761904756, 1.6877904761904756, 1.6877904761904756, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.607790476190477, 1.331961904761905, 1.331961904761905, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2799619047619044, 1.2399619047619048, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2690666666666663, 1.2454095238095235, 1.417485714285714, 1.417485714285714, 1.417485714285714, 1.417485714285714, 1.417485714285714, 1.417485714285714, 1.417485714285714, 1.417485714285714, 1.417485714285714, 1.417485714285714, 1.417485714285714, 1.430590476190476, 1.430590476190476, 1.430590476190476, 1.430590476190476, 1.430590476190476, 1.430590476190476, 1.430590476190476]
deltashiftpp = [1.428269418002137, 1.3842046980409806, 1.3226901903947794, 1.2569337454746945, 1.2134755945126212, 1.1671608161975962, 1.1285484445150324, 1.0967331031235377, 1.0741722660592028, 1.071605420823232, 1.0758336261142625, 1.029542410125328, 1.02382162700269, 1.0098598117477007, 0.9898883663144737, 0.9788285931922062, 0.9785892352681296, 0.9416492599209799, 0.9605846634716915, 0.9375587792394655, 0.9447246614668966, 0.945161775589253, 0.9399712154578718, 0.9186305553601987, 0.9117973689293005, 0.9236078536423071, 0.9301055103103615, 0.9108659924733096, 0.8924861893047491, 0.8881578501407033, 0.8865459284293885, 0.8967585536624562, 0.8921370868132428, 0.8830703438476886, 0.8779588152618792, 0.8538417343173605, 0.8400590650962819, 0.8181658575279893, 0.8172651223414408, 0.810357298938862, 0.8092966757494137, 0.7973859821136352, 0.7976732506003996, 0.6830726062128524, 0.6793786690449071, 0.6715645390441475, 0.6618250954615906, 0.6711921319951426, 0.6688168798196795, 0.6582210406734904, 0.6555858726930075, 0.6450668337366716, 0.6375272736091329, 0.6408924037528536, 0.6385365173556654, 0.6534621309936283, 0.6515194920061778, 0.6468591295850267, 0.6473722854481616, 0.646378687111124, 0.6510199402818843, 0.6518043876957376, 0.525950097732252, 0.5255618184040324, 0.529172285189376, 0.5247375624171826, 0.5218642111513992, 0.5247516344119534, 0.5227987308888347, 0.5143359602715298, 0.5167052289958609, 0.5113902534756702, 0.5079779138053606, 0.5095508120703165, 0.5073921481650401, 0.5074728847281329, 0.506380203781856, 0.504421264149476, 0.4966462647199166, 0.3957148362244154, 0.3908052619011661, 0.391169079615091, 0.39354338190054927, 0.39344774397778126, 0.39792398120516176, 0.3830779231378264, 0.37223809957231097, 0.3738657064620277, 0.3816089791670361, 0.379281813593701, 0.37296584948800116, 0.3727240951141011, 0.3747045122807279, 0.3720768329896764, 0.37081365930164567, 0.366705665784592, 0.3685801252222823, 0.3675431771473449, 0.36217120644311845, 0.2979029763576571, 0.29837286537720065, 0.2983849083895689, 0.3052042244449063, 0.3086542095914541, 0.3055282954346631, 0.30871561058163816, 0.30763890184479803, 0.3069631358877987, 0.3110641552248426, 0.3051903799095042, 0.301715387133458, 0.39143616545487814, 0.38369160000186, 0.37890066479282597, 0.37975458555541336, 0.3764765957425438, 0.3815890525419568, 0.37686789477773097]
deltashiftpprest = [1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4753780568719097, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.4941524817978113, 1.2672092749915476, 1.2672092749915476, 1.2672092749915476, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.213250990252159, 1.334576437122676, 1.334576437122676, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2701517421259465, 1.2180679285073868, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1858948343630937, 1.1361426302850912, 1.2843683396067194, 1.2843683396067194, 1.2843683396067194, 1.2843683396067194, 1.2843683396067194, 1.2843683396067194, 1.2843683396067194, 1.2843683396067194, 1.2843683396067194, 1.2843683396067194, 1.2843683396067194, 1.230168914532385, 1.230168914532385, 1.230168914532385, 1.230168914532385, 1.230168914532385, 1.230168914532385, 1.230168914532385]

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
x = np.arange(len(hutch))

plt.plot(x, hutch, label="Hutchinson")
plt.plot(x,  hutchpp, label="Hutchinson++")
plt.plot(x, deltashift, label="DeltaShift")
plt.plot(x,  deltashiftrest, label="DeltaShift Restart")
plt.plot(x, deltashiftpp, label="DeltaShift++")
plt.plot(x,  deltashiftpprest, label="DeltaShift++ Restart")

plt.legend()
plt.xlabel("Time step(i)")
plt.ylabel("$\\frac{|tr(A_i^3) - t_i|}{\max_i tr(A_i^3)}$")
plt.title("Average error for 50 trials, Dubki triangle counting")

plt.show()

# %%
hutch = [3.5197735045089874e-05, 3.6088816944905574e-05, 0.00033912118462556246, 0.0007730194250725469, 0.0007898531025281298, 0.0007015911621317146, 0.0009215629373278535, 0.0011124529450990015, 0.0013027088915146144, 0.001116127910740653, 0.001157263969335466, 0.001269332908920404, 0.001294684789633331, 0.0012740715619531076, 0.0012588481912129698, 0.0013411920897750257, 0.0011863851379599127, 0.0013653751582372795, 0.0013062105989591326, 0.0010782736279069064, 0.0012940714275478105, 0.0015446684931800872, 0.001207478024928665, 0.0012400379701858106, 0.0014639141476455713, 0.0019757509297675556, 0.0016488396697185077, 0.002081731687114807, 0.0015187369606665438, 0.001472400577932329, 0.0024610967135031726, 0.0023553775988110377, 0.0023192060933751074, 0.002681497490771397, 0.0024726593529458994, 0.0023961348059397037, 0.002774717894640607, 0.002407839627563821, 0.0029294332131510527, 0.003308377083756105, 0.0028226405399493964, 0.0032685461002481, 0.002840254489599692, 0.0030083680142511064, 0.0033208444122930243, 0.003331047263894032, 0.002830784495113206, 0.0036352894548846754, 0.002651256118658499, 0.003406771150463247, 0.003218605230559714, 0.004146037090665403, 0.0030822923248558305, 0.0037073120077654198, 0.003470715649276895, 0.003290285983725214, 0.002893855785981523, 0.0035216306196747425, 0.00356795861317796, 0.0033421622934613256, 0.0037082173906593015, 0.0041703011369419694, 0.004210577168234038]
hutchpp = [0.18308400140563613, 0.18316209051192878, 0.1843225735673172, 0.18624745620323221, 0.18846069472321364, 0.18985458572432914, 0.18986236690490885, 0.1914178604479613, 0.2038441168376478, 0.20425720031145012, 0.20760987468414924, 0.20867685902420927, 0.20887438902130728, 0.20955073621982442, 0.20947043753804265, 0.21178373035482717, 0.2138425155043426, 0.21464314373718543, 0.21453816069043113, 0.21532826000707167, 0.21645850542505474, 0.21652022634149287, 0.2184791527722046, 0.23156012550986788, 0.2331157571759201, 0.23443235789263686, 0.23915492947784006, 0.24380131783776757, 0.24706273808318502, 0.24664361878144914, 0.2877238114570055, 0.2884279425424544, 0.28900455525131646, 0.29487392421395736, 0.297845037816911, 0.3088240114364647, 0.3253358591934542, 0.33612143978604303, 0.3521130622796113, 0.3547743146043016, 0.35879689966347195, 0.37259545664252663, 0.3741704791430442, 0.3756341806487376, 0.37635418967224277, 0.3803224766004752, 0.38412524511680846, 0.385185166082252, 0.39280622096529344, 0.3930268342593915, 0.40273462969624524, 0.40328541089062314, 0.41217078435535925, 0.4151016672574267, 0.4149741420683965, 0.4191110099504632, 0.4212498345009939, 0.4218000645847668, 0.4582392949966661, 0.45835664772451046, 0.4617805037827633, 0.4696148209400338, 0.4862897703020648]
deltashift = [2.3168129396710424e-05, 5.331304117260729e-05, 0.0005767828041439749, 0.0008372755450390857, 0.000840460882207545, 0.0008395192677794276, 0.0007538159932052864, 0.0007535880836601918, 0.0013152264690846813, 0.0012546639637900034, 0.0012730878156613568, 0.001153888391504426, 0.0010088211567186734, 0.0008053362655419283, 0.0006896529995997721, 0.0007876665840801275, 0.0007922503358896864, 0.0007540982930352858, 0.0006383161901650067, 0.0006587915092465361, 0.0006927571751168415, 0.0005497791912246934, 0.0006319670268931579, 0.001070147113533917, 0.0009802293973574009, 0.0008609393546053695, 0.0009088383946096643, 0.0012718780191267134, 0.0011849557140684941, 0.0010007684626037077, 0.002331581029907236, 0.002021667991466752, 0.0019133645624086904, 0.001918989626666176, 0.0019502867123690404, 0.0021074193111788363, 0.002077728479645194, 0.0018801712619900626, 0.002017566318820828, 0.001861092891766114, 0.0017033223414528046, 0.001808445125938991, 0.001865437282897532, 0.0017070840407747753, 0.0016246683705811637, 0.0016188432337139803, 0.0018683154828625407, 0.0016552198585998467, 0.0019004972085754066, 0.001799959239800138, 0.0018224678512463385, 0.0015949071009913568, 0.0016849303485634956, 0.0017210598964572082, 0.001460171807869103, 0.0017043132026538438, 0.001761102563385853, 0.0016852739990725453, 0.0025699235003787944, 0.002387037344773175, 0.002215781772384702, 0.002130711434231029, 0.0023657940472601876]
deltashiftrest = [2.628691604631647e-05, 4.068345799111014e-05, 0.0003419656888715468, 0.0007908619184931632, 0.0007842966878332226, 0.0008464337231887971, 0.0008438766325567337, 0.0008070894613451642, 0.0011460276341001526, 0.0011274591887337892, 0.0011790421493351549, 0.0012267713864016665, 0.0012099549142341353, 0.0011988301794675583, 0.0012336811474523682, 0.0012434967651566984, 0.0011979018947354562, 0.0012173005897087915, 0.0012154441690840469, 0.0012249083448036529, 0.001031962187828868, 0.001026182697181327, 0.001136218140896762, 0.0013967053507214064, 0.0014656620674280783, 0.0015973776312441425, 0.0016218406311655732, 0.0017864032679607072, 0.0017184591593462004, 0.0017251695779629899, 0.0022352799641005903, 0.002245170061988048, 0.0022704624608909448, 0.002197282685156934, 0.002240600274021846, 0.0024713146534269363, 0.002686689732148136, 0.002667591714135534, 0.0029475759616391893, 0.0029785244202947436, 0.001991716218806137, 0.0023206056312940274, 0.0023971006334498604, 0.002380009094668401, 0.0023844087353957154, 0.0023813946062821987, 0.0025762482215579423, 0.0025833323976560984, 0.0026543345499185577, 0.0026575276799820787, 0.0025800101951193783, 0.0025686945075574365, 0.0027026630885170926, 0.0027593627419873457, 0.0027696406805892133, 0.002858170594490198, 0.0029191464307530873, 0.0029857559305878634, 0.003495527065861803, 0.0035020245380483913, 0.0032733421614656298, 0.0033484260882925025, 0.0035868120578014624]
deltashiftpp = [0.18481858306256582, 0.18475275899053023, 0.18472291777345884, 0.18511827193524358, 0.18628964791008928, 0.1866477483044436, 0.18696255630116554, 0.18757387648629278, 0.20015222251632683, 0.20116577459875903, 0.20385439672452216, 0.2047535895892556, 0.20547462101189673, 0.20613772254684246, 0.2067233524187478, 0.2075671814663977, 0.20858349028940285, 0.20921525898284377, 0.20979912038174825, 0.2103468912957203, 0.21089340005899188, 0.2114048873491461, 0.2121094308477035, 0.22455446394587308, 0.22587638970504045, 0.2271530145469101, 0.23134426009711095, 0.23441132608231668, 0.23661232355851994, 0.23784353829368235, 0.27928649408516965, 0.2821087594241916, 0.2839357337424568, 0.28870390444297267, 0.29194645310995193, 0.3008382286942411, 0.3172591744580561, 0.3275494136838347, 0.34326963039088215, 0.34558055745956745, 0.34960798469883436, 0.3617914645816762, 0.3635928630671599, 0.3654550452507946, 0.36765391575652684, 0.3698275005655352, 0.37250428813519165, 0.3740356160941067, 0.37951869008334227, 0.3809304868602669, 0.38960249947833175, 0.39101191715241224, 0.39958463623102647, 0.40192693572502064, 0.4031983916128338, 0.405102414499145, 0.4063898999861671, 0.40757945191497796, 0.44451133427563955, 0.4466824156799907, 0.4492359264787788, 0.4552500662120007, 0.47259621261131]
deltashiftpprest = [0.1848217004151109, 0.1848217004151109, 0.18478351580833008, 0.18498728263917733, 0.18588887650293628, 0.18590713261049177, 0.18590713267623182, 0.18611035279846075, 0.1970923981528835, 0.19709240111664084, 0.19868017264271307, 0.1986359857358868, 0.19864158398880782, 0.19859778307640125, 0.1985977838630675, 0.19876755788108297, 0.1991094930687751, 0.19907246347524674, 0.19907273243681192, 0.19905350189482518, 0.21423389594201644, 0.21423333384096402, 0.21434990363618314, 0.22501357230760832, 0.22505963676899982, 0.22507670077019337, 0.22785378254476524, 0.2293896824501678, 0.2300185754833427, 0.2300185754833429, 0.2674091666791908, 0.26740839938211797, 0.2673541581160117, 0.2703075976463222, 0.27190508495281723, 0.2791099236347821, 0.29334551378648305, 0.30132352206477925, 0.31452733434737185, 0.3147752440226054, 0.3542040125226725, 0.3635107535952967, 0.3635475499006439, 0.3635264084944765, 0.36393943083428604, 0.36449679846276334, 0.36572037842530863, 0.3657462574163742, 0.36968412831494346, 0.3696841123007244, 0.37668487641341875, 0.3766874186676094, 0.3837086975416717, 0.3844893790426791, 0.38448822645235864, 0.38499685126183125, 0.3849552922576502, 0.38491959738441717, 0.41826257056772287, 0.41826257056772287, 0.45534124071899357, 0.45915573400933823, 0.474151405732213]

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
x = np.arange(len(hutch))

plt.plot(x, hutch, label="Hutchinson")
plt.plot(x,  hutchpp, label="Hutchinson++")
plt.plot(x, deltashift, label="DeltaShift")
plt.plot(x,  deltashiftrest, label="DeltaShift Restart")
plt.plot(x, deltashiftpp, label="DeltaShift++")
plt.plot(x,  deltashiftpprest, label="DeltaShift++ Restart")

plt.legend()
plt.xlabel("Time step(i)")
plt.ylabel("$\\frac{|tr(\exp(A)) - t_i|}{\max_i tr(\exp(A))}$")
plt.title("Average error for 50 trials, Innopolis natural connectivity")

plt.show()

# %%
x = np.arange(len(hutch))

plt.plot(x, hutch, label="Hutchinson")
plt.plot(x, deltashift, label="DeltaShift")
plt.plot(x,  deltashiftrest, label="DeltaShift Restart")

plt.legend()
plt.xlabel("Time step(i)")
plt.ylabel("$\\frac{|tr(\exp(A)) - t_i|}{\max_i tr(\exp(A))}$")
plt.title("Average error for 50 trials, Innopolis natural connectivity")

plt.show()
